# %%
from Dynamics import univariate_dynamics, univariate_plot

# %%
""" 
Functions will all be in the form of f(Xt+1) = f(Xt) - define
function by using Xt.

Use numpy for math notation. E.g. np.sqrt(Xt)

"""

def f(Xt):
    
   # return 1/(1.01) * .95 * Xt + .2*Xt**(1/3)
    
    return Xt**2

# %%
# setting the initial condition and calling the dynamics function

initial_condition = .5

convergence, dynamic_path = univariate_dynamics(f, initial_condition)

convergence
# Out:
# 0.0

# %%
univariate_plot(f, dynamic_path)
